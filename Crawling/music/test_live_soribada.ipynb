# %% [markdown]
# # 라이브러리 로드

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import time, random
from tqdm import tqdm
from datetime import datetime
from selenium import webdriver

# %%
# https://www.soribada.com/music/chart/daily/20220328

# %%
url = 'https://www.soribada.com/music/chart/daily/20220315'
# 페이지 접속
headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.117 Safari/537.36'}
# 지니뮤직 url
data = requests.get(url, headers=headers)
# soup : html형식
soup = bs(data.text, 'lxml')
soup.title.text
# Out:
# '소리바다'

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html lang="ko" xml:lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0,user-scalable=no" name="viewport"/>
# <title>소리바다</title>
# <!-- <meta name="fragment" content="!"> -->
# <meta content="182687168411984" property="fb:app_id"/>
# <meta content="소리바다" property="og:title"/>
# <meta content="Soribada" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="http://image.soribada.com/image/main/icon_logo.png" property="og:image"/>
# <meta content="https://www.soribada.com/music/chart/daily/20220315" property="og:url"/>
# <meta content="Share The Rhythm" property="og:description"/>
# <meta content="soribada30://" property="al:ios:url"/>
# <meta content="346528006" property="al:ios:app_store_id"/>
# <meta content="soribada" property="al:ios:app_name"/>
# ...

# %%
url = 'https://www.soribada.com/music/chart/daily/20220101'
# 페이지 접속
headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.117 Safari/537.36'}
# 지니뮤직 url
data = requests.get(url, headers=headers)
# soup : html형식
soup = bs(data.text, 'lxml')
soup.title.text
# Out:
# '소리바다'

# %%
# 곡 제목
songs = soup.find_all('span', class_='link-type1')
len(songs)
# Out:
# 0

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html lang="ko" xml:lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0,user-scalable=no" name="viewport"/>
# <title>소리바다</title>
# <!-- <meta name="fragment" content="!"> -->
# <meta content="182687168411984" property="fb:app_id"/>
# <meta content="소리바다" property="og:title"/>
# <meta content="Soribada" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="http://image.soribada.com/image/main/icon_logo.png" property="og:image"/>
# <meta content="https://www.soribada.com/music/chart/daily/20220101" property="og:url"/>
# <meta content="Share The Rhythm" property="og:description"/>
# <meta content="soribada30://" property="al:ios:url"/>
# <meta content="346528006" property="al:ios:app_store_id"/>
# <meta content="soribada" property="al:ios:app_name"/>
# ...

# %%
url = 'https://www.soribada.com/music/chart/daily/20220315'
driver = webdriver.Chrome('../chromedriver')
driver.get(url)
driver.maximize_window()
# Out:
# <ipython-input-21-80f5dee276f8>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('../chromedriver')

# %%
soup = bs(driver.page_source, 'lxml')
soup.title.text
# Out:
# '소리바다'

# %%
# 곡 제목
songs = soup.find_all('span', class_='link-type1')
len(songs)
# Out:
# 0

# %%
url = 'https://www.soribada.com/music/chart/daily/20220314'
driver = webdriver.Chrome('../chromedriver')
driver.get(url)
driver.maximize_window()
# Out:
# <ipython-input-20-a97542d10154>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('../chromedriver')

# %%
url = 'https://www.soribada.com/music/chart/daily/20220216'
driver = webdriver.Chrome('../chromedriver')
driver.get(url)
driver.maximize_window()
# Out:
# <ipython-input-24-ea6158127a3a>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('../chromedriver')

# %%
url = 'https://www.soribada.com/music/chart/daily/20220215'
driver = webdriver.Chrome('../chromedriver')
driver.get(url)
driver.maximize_window()
# Out:
# <ipython-input-25-9a52de107aa7>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('../chromedriver')
