# %% [markdown]
# # 음원의 전주와 이번주 순위 평균 비교
# * 3-2-1. Top 50위 진입 급상승 음원 현황
#     * Top50_rank_change_df.xlsx
# * 3-2-2. Top 50위 이탈 급상승 음원 현황
#     * Top50_100_rank_change_df.xlsx
# * 3-2-3. Top 10위 음원 현황
#     * Top10_rank_change_df.xlsx

# %% [markdown]
# ## 라이브러리

# %%
import pandas as pd
import os

# %%
f_path = 'c:/data/Wantreez/Crawling/music'
try:
    os.chdir(f_path)
except:
    pass

# %%
code_path = os.getcwd().replace('\\', '/')
code_path
# Out:
# 'c:/data/Wantreez/Crawling/music'

# %% [markdown]
# ## 날짜 설정

# %%
# 전 주 파일 날짜(일주일)
start_date = '2022-05-09'
end_date = '2022-05-15'
# 비교할 파일 날짜(일주일)
new_start_date = '2022-05-16'
new_end_date = '2022-05-22'
new_dates_df = pd.date_range(new_start_date, new_end_date).astype(str)

# %% [markdown]
# ## 3-2-3. Top 10위 음원 현황

# %%
# 음원 사이트
site_list = ['bugs', 'flo', 'genie', 'melon', 'vibe']
top10_df = pd.DataFrame()
for site_name in site_list:
    # code_path = 'c:/data/Wantreez/Crawling/music'
    folder_path = f'crawled_data/mod_{site_name}'
    site_path = os.path.join(code_path, folder_path)

    # 파일 이름들
    file_list = os.listdir(site_path)

    # 전체 df 생성
    total_df = pd.DataFrame()
    for one in file_list:
        one_path = os.path.join(site_path, one)
        temp = pd.read_excel(one_path)
        total_df = pd.concat([total_df, temp], ignore_index=True)
    total_df['날짜'] = total_df['날짜'].astype(str)

    # 전주, 이번주 df
    before_df = total_df[ (total_df['날짜'] >= start_date) & (total_df['날짜'] <= end_date) ].reset_index(drop=True)
    current_df = total_df[ (total_df['날짜'] >= new_start_date) & (total_df['날짜'] <= new_end_date) ].reset_index(drop=True)

    # 전주 음원들의 순위 평균
    before_df['전주순위평균'] = before_df.groupby(['사이트', '곡', '가수'])['순위'].transform('mean')
    before_df['전주순위평균'] = round(before_df['전주순위평균'], 1)
    # 이번주 음원들의 순위 평균
    current_df['이번주순위평균'] = current_df.groupby(['사이트', '곡', '가수'])['순위'].transform('mean')
    current_df['이번주순위평균'] = round(current_df['이번주순위평균'], 1)

    # 전주, 이번주 Top10 df
    # before_top10_df = before_df[before_df['순위'] <= 10].reset_index(drop=True)
    current_top10_df = current_df[current_df['이번주순위평균'] <= 10].reset_index(drop=True)

    # 전주, 이번주 Top10 df 병합
    bvsc_df = pd.merge(before_df.drop_duplicates(['곡', '가수']).reset_index(drop=True), current_top10_df.drop_duplicates(['곡', '가수']).reset_index(drop=True), how='inner', on=['곡', '가수'])
    bvsc_df = bvsc_df.drop('사이트_y', axis=1)
    bvsc_df = bvsc_df.rename(columns={'사이트_x':'사이트'})
    
    # 전주 대비 상승폭
    bvsc_df['전주 대비 상승폭'] = bvsc_df['전주순위평균'] - bvsc_df['이번주순위평균']
    bvsc_df = bvsc_df[['이번주순위평균', '곡', '가수', '전주 대비 상승폭', '사이트', '전주순위평균']]
    top10_df = pd.concat([top10_df, bvsc_df])

# 파일 저장
# code_path = 'c:/data/Wantreez/Crawling/music'
save_folder = f'crawled_data/outlier_data/{new_start_date}_{new_end_date}'
save_folder2 = os.path.join(code_path, save_folder)
os.makedirs(save_folder2, exist_ok=True)
file_name = f'{new_start_date}_{new_end_date}_Top10_rank_change_df.xlsx'
# save_folder2 = 'c:/data/Wantreez/Crawling/music/crawled_data/outlier_data/{new_start_date}_{new_end_date}'
top10_rank_change_path = os.path.join(save_folder2, file_name)
top10_df.to_excel(top10_rank_change_path, index=False, encoding='utf-8')
print(f'{file_name} 출력완료.')
# Out:
# 2022-05-16_2022-05-22_Top10_rank_change_df.xlsx 출력완료.

# %% [markdown]
# ## 3-2-1. Top 50위 진입 급상승 음원 현황

# %%
# 음원 사이트
site_list = ['bugs']
# top50_df = pd.DataFrame()
for site_name in site_list:
    # code_path = 'c:/data/Wantreez/Crawling/music'
    folder_path = f'crawled_data/mod_{site_name}'
    site_path = os.path.join(code_path, folder_path)

    # 파일 이름들
    file_list = os.listdir(site_path)

    # 전체 df 생성
    total_df = pd.DataFrame()
    for one in file_list:
        one_path = os.path.join(site_path, one)
        temp = pd.read_excel(one_path)
        total_df = pd.concat([total_df, temp], ignore_index=True)
    total_df['날짜'] = total_df['날짜'].astype(str)

    # 전주, 이번주 df
    before_df = total_df[ (total_df['날짜'] >= start_date) & (total_df['날짜'] <= end_date) ].reset_index(drop=True)
    new_df = total_df[ (total_df['날짜'] >= new_start_date) & (total_df['날짜'] <= new_end_date) ].reset_index(drop=True)

    # 전주 음원들의 순위 평균
    before_df['전주평균순위'] = before_df.groupby(['사이트', '곡', '가수'])['순위'].transform('mean')

# %%
before_df.groupby(['사이트', '곡', '가수'])['순위'].transform('mean')[220]
# Out:
# 20.428571428571427

# %%
before_df.groupby(['사이트', '곡', '가수'])['순위'].transform('mean')[103]
# Out:
# 20.428571428571427

# %%
before_df
# Out:
#       사이트          날짜   순위                                      곡  \
# 0    Bugs  2022-05-09    1                                   내 곁에
# 1    Bugs  2022-05-09    2  That That (prod. & feat. SUGA of BTS)
# 2    Bugs  2022-05-09    3                              LOVE DIVE
# 3    Bugs  2022-05-09    4                                 TOMBOY
# 4    Bugs  2022-05-09    5                                 기억해 줘요
# ..    ...         ...  ...                                    ...
# 695  Bugs  2022-05-15   96                                내 손을 잡아
# 696  Bugs  2022-05-15   97                     일종의 고백 (Male Ver.)
# 697  Bugs  2022-05-15   98          Cooped Up (feat. Roddy Ricch)
# 698  Bugs  2022-05-15   99                            My Universe
# 699  Bugs  2022-05-15  100                                  벌써 일년
#
#                       가수                           앨범        소속사 소속사_분류  \
# 0           태연 (TAEYEON)          우리들의 블루스 OST Part 6         SM     SM
# 1               싸이 (PSY)                          싸다9   P NATION     기타
# 2              IVE (아이브)                    LOVE DIVE        스타쉽    스타쉽
# 3                (여자)아이들                  I NEVER DIE       CUBE     기타
# 4                    다비치          우리들의 블루스 OST Part 5   WAKE ONE     기타
# ..                   ...                          ...        ...    ...
# 695              아이유(IU)  최고의 사랑 (MBC 수목드라마) - Part.4       EDAM     기타
# 696                  곽진언           나의 해방일지 OST Part 9  MusicFarm     기타
# 697  Post Malone(포스트 말론)                    Cooped Up         해외     기타
# 698      Coldplay(콜드플레이)                  My Universe         해외     기타
# 699  브라운 아이즈(Brown Eyes)                   Brown Eyes         기타     기타
#
#          전주평균순위
# 0     20.428571
# 1      1.714286
# 2      3.428571
# 3      6.714286
# 4     43.000000
# ..          ...
# 695   75.000000
# 696   58.750000
# 697   93.000000
# 698   99.000000
# 699  100.000000
#
# [700 rows x 9 columns]

# %%
before_df[(before_df['곡']=='내 곁에') & (before_df['가수']=='태연 (TAEYEON)')]
# Out:
#       사이트          날짜  순위     곡            가수                   앨범 소속사 소속사_분류  \
# 0    Bugs  2022-05-09   1  내 곁에  태연 (TAEYEON)  우리들의 블루스 OST Part 6  SM     SM
# 103  Bugs  2022-05-10   4  내 곁에  태연 (TAEYEON)  우리들의 블루스 OST Part 6  SM     SM
# 220  Bugs  2022-05-11  21  내 곁에  태연 (TAEYEON)  우리들의 블루스 OST Part 6  SM     SM
# 325  Bugs  2022-05-12  26  내 곁에  태연 (TAEYEON)  우리들의 블루스 OST Part 6  SM     SM
# 430  Bugs  2022-05-13  31  내 곁에  태연 (TAEYEON)  우리들의 블루스 OST Part 6  SM     SM
# 525  Bugs  2022-05-14  26  내 곁에  태연 (TAEYEON)  우리들의 블루스 OST Part 6  SM     SM
# 633  Bugs  2022-05-15  34  내 곁에  태연 (TAEYEON)  우리들의 블루스 OST Part 6  SM     SM
#
#         전주평균순위
# 0    20.428571
# 103  20.428571
# 220  20.428571
# 325  20.428571
# 430  20.428571
# 525  20.428571
# 633  20.428571

# %%
# 음원 사이트
site_list = ['bugs', 'flo', 'genie', 'melon', 'vibe']
top50_df = pd.DataFrame()
for site_name in site_list:
    # code_path = 'c:/data/Wantreez/Crawling/music'
    folder_path = f'crawled_data/mod_{site_name}'
    site_path = os.path.join(code_path, folder_path)

    # 파일 이름들
    file_list = os.listdir(site_path)

    # 전체 df 생성
    total_df = pd.DataFrame()
    for one in file_list:
        one_path = os.path.join(site_path, one)
        temp = pd.read_excel(one_path)
        total_df = pd.concat([total_df, temp], ignore_index=True)
    total_df['날짜'] = total_df['날짜'].astype(str)

    # 전주, 이번주 df
    before_df = total_df[ (total_df['날짜'] >= start_date) & (total_df['날짜'] <= end_date) ].reset_index(drop=True)
    current_df = total_df[ (total_df['날짜'] >= new_start_date) & (total_df['날짜'] <= new_end_date) ].reset_index(drop=True)

    # 전주 음원들의 순위 평균
    before_df['전주순위평균'] = before_df.groupby(['사이트', '곡', '가수'])['순위'].transform('mean')
    before_df['전주순위평균'] = round(before_df['전주순위평균'], 1)
    # 이번주 음원들의 순위 평균
    current_df['이번주순위평균'] = current_df.groupby(['사이트', '곡', '가수'])['순위'].transform('mean')
    current_df['이번주순위평균'] = round(current_df['이번주순위평균'], 1)

    # 전주, 이번주 Top50 df
    # before_top50_df = before_df[before_df['순위'] <= 50].reset_index(drop=True)
    current_top50_df = current_df[current_df['이번주순위평균'] <= 50].reset_index(drop=True)

    # 전주, 이번주 Top50 df 병합
    bvsc_df = pd.merge(before_df.drop_duplicates(['곡', '가수']).reset_index(drop=True), current_top50_df.drop_duplicates(['곡', '가수']).reset_index(drop=True), how='inner', on=['곡', '가수'])
    bvsc_df = bvsc_df.drop('사이트_y', axis=1)
    bvsc_df = bvsc_df.rename(columns={'사이트_x':'사이트'})
    
    # 전주 대비 상승폭
    bvsc_df['전주 대비 상승폭'] = bvsc_df['전주순위평균'] - bvsc_df['이번주순위평균']
    bvsc_df = bvsc_df[['이번주순위평균', '곡', '가수', '전주 대비 상승폭', '사이트', '전주순위평균']].reset_index(drop=True)
    top50_df = pd.concat([top50_df, bvsc_df])

# 50위 곡 중 이상치 곡만 추출
# save_folder2 = 'c:/data/Wantreez/Crawling/music/crawled_data/outlier_data/{new_start_date}_{new_end_date}'
outlier_file_name = f'{new_start_date}_{new_end_date}_total_outlier.xlsx'
outlier_path = os.path.join(save_folder2, outlier_file_name)
outlier_df = pd.read_excel(outlier_path)

top50_outlier_df = pd.DataFrame()
for i in range(outlier_df.shape[0]):
    title = outlier_df['곡'][i]
    artist = outlier_df['가수'][i]
    temp = top50_df[ (top50_df['곡'] == title) & (top50_df['가수'] == artist)].reset_index(drop=True)
    top50_outlier_df = pd.concat([top50_outlier_df, temp], ignore_index=True)

# 파일 저장
file_name2 = f'{new_start_date}_{new_end_date}_Top50_rank_change_df.xlsx'
save_top50_outlier_path = os.path.join(save_folder2, file_name2)
top50_outlier_df.to_excel(save_top50_outlier_path, index=False, encoding='utf-8')
print(f'{file_name2} 출력완료.')
# Out:
# 2022-05-16_2022-05-22_Top50_rank_change_df.xlsx 출력완료.

# %%
before_df
# Out:
#       사이트          날짜   순위                                      곡  \
# 0    Vibe  2022-05-09    1                              LOVE DIVE
# 1    Vibe  2022-05-09    2  That That (prod. & feat. SUGA of BTS)
# 2    Vibe  2022-05-09    3                                 TOMBOY
# 3    Vibe  2022-05-09    4                   봄여름가을겨울 (Still Life)
# 4    Vibe  2022-05-09    5                         Feel My Rhythm
# ..    ...         ...  ...                                    ...
# 695  Vibe  2022-05-15   96                                     서랍
# 696  Vibe  2022-05-15   97                                 아무래도 난
# 697  Vibe  2022-05-15   98                                    겨울잠
# 698  Vibe  2022-05-15   99                              Starlight
# 699  Vibe  2022-05-15  100                      버퍼링 (Glitch Mode)
#
#                     가수                                         앨범  \
# 0             IVE(아이브)                                  LOVE DIVE
# 1             싸이 (PSY)                                        싸다9
# 2             (여자) 아이들                                I NEVER DIE
# 3         BIGBANG (빅뱅)                       봄여름가을겨울 (Still Life)
# 4    Red Velvet (레드벨벳)  'The ReVe Festival 2022 - Feel My Rhythm'
# ..                 ...                                        ...
# 695               10CM                         그 해 우리는 OST Part 1
# 696       주시크 (Joosiq)                                     아무래도 난
# 697            아이유(IU)                                        조각집
# 698         태일 (TAEIL)                       스물다섯 스물하나 OST Part 1
# 699          NCT DREAM                Glitch Mode - The 2nd Album
#
#              소속사 소속사_분류  전주순위평균
# 0            스타쉽    스타쉽     1.0
# 1       P NATION     기타     2.0
# 2           CUBE     기타     3.0
# 3             YG     YG     4.0
# 4             SM     SM     5.0
# ..           ...    ...     ...
# 695  매직스트로베리 사운드     기타    94.0
# 696        레시피뮤직     기타    96.4
# 697         EDAM     기타    96.6
# 698           SM     SM    90.9
# 699           SM     SM    96.6
#
# [700 rows x 9 columns]

# %%
new_df
# Out:
#       사이트          날짜   순위                                      곡  \
# 0    Vibe  2022-05-16    1                              LOVE DIVE
# 1    Vibe  2022-05-16    2  That That (prod. ＆ feat. SUGA of BTS)
# 2    Vibe  2022-05-16    3                                 TOMBOY
# 3    Vibe  2022-05-16    4                   봄여름가을겨울 (Still Life)
# 4    Vibe  2022-05-16    5                         Feel My Rhythm
# ..    ...         ...  ...                                    ...
# 695  Vibe  2022-05-22   96                                 아무래도 난
# 696  Vibe  2022-05-22   97                                     서랍
# 697  Vibe  2022-05-22   98                              Starlight
# 698  Vibe  2022-05-22   99                   Can't Control Myself
# 699  Vibe  2022-05-22  100                          왜 이제와서야 (Why)
#
#                     가수                                         앨범  \
# 0             IVE(아이브)                                  LOVE DIVE
# 1             싸이 (PSY)                                        싸다9
# 2             (여자) 아이들                                I NEVER DIE
# 3         BIGBANG (빅뱅)                       봄여름가을겨울 (Still Life)
# 4    Red Velvet (레드벨벳)  'The ReVe Festival 2022 - Feel My Rhythm'
# ..                 ...                                        ...
# 695       주시크 (Joosiq)                                     아무래도 난
# 696               10CM                         그 해 우리는 OST Part 1
# 697         태일 (TAEIL)                       스물다섯 스물하나 OST Part 1
# 698       태연 (TAEYEON)                       Can't Control Myself
# 699                황치열                                 By My Side
#
#              소속사 소속사_분류  이번주순위평균
# 0            스타쉽    스타쉽      1.0
# 1       P NATION     기타      2.4
# 2           CUBE     기타      2.6
# 3             YG     YG      4.0
# 4             SM     SM      5.0
# ..           ...    ...      ...
# 695        레시피뮤직     기타     97.0
# 696  매직스트로베리 사운드     기타     96.6
# 697           SM     SM     96.0
# 698           SM     SM     97.9
# 699         TEN2     기타    100.0
#
# [700 rows x 9 columns]

# %%
test_merge = pd.merge(before_df.drop_duplicates(['곡', '가수']).reset_index(drop=True), new_df.drop_duplicates(['곡', '가수']).reset_index(drop=True), how='inner', on=['곡', '가수'])
test_merge
# Out:
#    사이트_x        날짜_x  순위_x                                      곡  \
# 0   Vibe  2022-05-09     1                              LOVE DIVE
# 1   Vibe  2022-05-09     3                                 TOMBOY
# 2   Vibe  2022-05-09     4                   봄여름가을겨울 (Still Life)
# 3   Vibe  2022-05-09     5                         Feel My Rhythm
# 4   Vibe  2022-05-09     6                                 사랑인가 봐
# ..   ...         ...   ...                                    ...
# 94  Vibe  2022-05-09   100                      버퍼링 (Glitch Mode)
# 95  Vibe  2022-05-11     2  That That (prod. ＆ feat. SUGA of BTS)
# 96  Vibe  2022-05-12    63                              초록을거머쥔우리는
# 97  Vibe  2022-05-13    92                                     초대
# 98  Vibe  2022-05-15    47                                 안녕이란 말
#
#                    가수                                       앨범_x     소속사_x  \
# 0            IVE(아이브)                                  LOVE DIVE       스타쉽
# 1            (여자) 아이들                                I NEVER DIE      CUBE
# 2        BIGBANG (빅뱅)                       봄여름가을겨울 (Still Life)        YG
# 3   Red Velvet (레드벨벳)  'The ReVe Festival 2022 - Feel My Rhythm'        SM
# 4     멜로망스(Melomance)                   사랑인가 봐 (사내맞선 OST 스페셜 트랙)     ABYSS
# ..                ...                                        ...       ...
# 94          NCT DREAM                Glitch Mode - The 2nd Album        SM
# 95           싸이 (PSY)                                        싸다9  P NATION
# 96                잔나비                     잔나비 소곡집 ll : 초록을거머쥔우리는     페포니뮤직
# 97    멜로망스(Melomance)                                         초대     ABYSS
# 98                정승환                                     안녕이란 말       안테나
#
#    소속사_분류_x  전주순위평균 사이트_y        날짜_y  순위_y  \
# 0       스타쉽     1.0  Vibe  2022-05-16     1
# 1        기타     3.0  Vibe  2022-05-16     3
# 2        YG     4.0  Vibe  2022-05-16     4
# 3        SM     5.0  Vibe  2022-05-16     5
# 4        기타     6.0  Vibe  2022-05-16     6
# ..      ...     ...   ...         ...   ...
# 94       SM    96.6  Vibe  2022-05-16    99
# 95       기타     2.0  Vibe  2022-05-16     2
# 96       기타    41.2  Vibe  2022-05-16    45
# 97       기타    80.3  Vibe  2022-05-16    63
# 98       기타    47.0  Vibe  2022-05-16    58
#
#                                          앨범_y     소속사_y 소속사_분류_y  이번주순위평균
# 0                                   LOVE DIVE       스타쉽      스타쉽      1.0
# 1                                 I NEVER DIE      CUBE       기타      2.6
# 2                        봄여름가을겨울 (Still Life)        YG       YG      4.0
# 3   'The ReVe Festival 2022 - Feel My Rhythm'        SM       SM      5.0
# 4                    사랑인가 봐 (사내맞선 OST 스페셜 트랙)     ABYSS       기타      6.0
# ..                                        ...       ...      ...      ...
# 94                Glitch Mode - The 2nd Album        SM       SM     99.3
# 95                                        싸다9  P NATION       기타      2.4
# 96                     잔나비 소곡집 ll : 초록을거머쥔우리는     페포니뮤직       기타     49.7
# 97                                         초대     ABYSS       기타     70.4
# 98                                     안녕이란 말       안테나       기타     50.1
#
# [99 rows x 16 columns]

# %%
top50_df
# Out:
#       이번주순위평균                 곡            가수  전주 대비 상승폭   사이트  전주순위평균
# 0        43.1              내 곁에  태연 (TAEYEON)      -22.7  Bugs    20.4
# 1        43.1              내 곁에  태연 (TAEYEON)      -22.7  Bugs    20.4
# 2        43.1              내 곁에  태연 (TAEYEON)      -22.7  Bugs    20.4
# 3        43.1              내 곁에  태연 (TAEYEON)      -22.7  Bugs    20.4
# 4        43.1              내 곁에  태연 (TAEYEON)      -22.7  Bugs    20.4
# ...       ...               ...           ...        ...   ...     ...
# 2251     44.3  That's Hilarious  Charlie Puth        7.0  Vibe    51.3
# 2252     50.1            안녕이란 말           정승환       -3.1  Vibe    47.0
# 2253     50.1            안녕이란 말           정승환       -3.1  Vibe    47.0
# 2254     50.1            안녕이란 말           정승환       -3.1  Vibe    47.0
# 2255     50.1            안녕이란 말           정승환       -3.1  Vibe    47.0
#
# [10931 rows x 6 columns]

# %% [markdown]
# ## 3-2-2. Top 50위 이탈 급상승 음원

# %%
# 음원 사이트
site_list = ['bugs', 'flo', 'genie', 'melon', 'vibe']
top50_100_df = pd.DataFrame()
for site_name in site_list:
    # code_path = 'c:/data/Wantreez/Crawling/music'
    folder_path = f'crawled_data/mod_{site_name}'
    site_path = os.path.join(code_path, folder_path)

    # 파일 이름들
    file_list = os.listdir(site_path)

    # 전체 df 생성
    total_df = pd.DataFrame()
    for one in file_list:
        one_path = os.path.join(site_path, one)
        temp = pd.read_excel(one_path)
        total_df = pd.concat([total_df, temp], ignore_index=True)
    total_df['날짜'] = total_df['날짜'].astype(str)

    # # 전주, 이번주 df
    # before_df = total_df[ (total_df['날짜'] >= start_date) & (total_df['날짜'] <= end_date)].reset_index(drop=True)
    # new_df = total_df[ (total_df['날짜'] >= new_start_date) & (total_df['날짜'] <= new_end_date)].reset_index(drop=True)

    # 전주, 이번주 df
    before_df = total_df[ (total_df['날짜'] >= start_date) & (total_df['날짜'] <= end_date) ].reset_index(drop=True)
    current_df = total_df[ (total_df['날짜'] >= new_start_date) & (total_df['날짜'] <= new_end_date) ].reset_index(drop=True)

    # 전주 음원들의 순위 평균
    before_df['전주순위평균'] = before_df.groupby(['사이트', '곡', '가수'])['순위'].transform('mean')
    before_df['전주순위평균'] = round(before_df['전주순위평균'], 1)
    # 이번주 음원들의 순위 평균
    current_df['이번주순위평균'] = current_df.groupby(['사이트', '곡', '가수'])['순위'].transform('mean')
    current_df['이번주순위평균'] = round(current_df['이번주순위평균'], 1)

    # 전주, 이번주 Top50~100 df
    # before_top50_100_df = before_df[before_df['순위'] > 50].reset_index(drop=True)
    current_top50_100_df = current_df[current_df['이번주순위평균'] > 50].reset_index(drop=True)

    # # 전주, 이번주 Top50~100 df
    # before_top50_100_df = before_df[before_df['순위'] > 50].reset_index(drop=True)
    # current_top50_100_df = new_df[new_df['순위'] > 50].reset_index(drop=True)
    # # 전주 Top50~100 음원들의 순위 평균
    # mean_before_top50_100_df = before_top50_100_df.groupby(['사이트', '곡', '가수']).agg('mean').reset_index()
    # mean_before_top50_100_df['순위'] = round(mean_before_top50_100_df['순위'], 1)
    # mean_before_top50_100_df.columns = ['사이트', '곡', '가수', '과거순위평균']

    # # 이번주 Top50~100 음원들의 순위 평균
    # mean_current_top50_100_df = current_top50_100_df.groupby(['사이트', '곡', '가수']).agg('mean').reset_index()
    # mean_current_top50_100_df['순위'] = round(mean_current_top50_100_df['순위'], 1)
    # mean_current_top50_100_df.columns = ['사이트', '곡', '가수', '현재순위평균']

    # 전주, 이번주 Top50~100 df 병합
    # bvsc_df = pd.merge(mean_before_top50_100_df, mean_current_top50_100_df, on=['곡', '가수'], how='inner')

    # 전주, 이번주 Top50~100 df 병합
    bvsc_df = pd.merge(before_df.drop_duplicates(['곡', '가수']).reset_index(drop=True), current_top50_100_df.drop_duplicates(['곡', '가수']).reset_index(drop=True), how='inner', on=['곡', '가수'])
    bvsc_df = bvsc_df.drop('사이트_y', axis=1)
    bvsc_df = bvsc_df.rename(columns={'사이트_x':'사이트'})
    
    # # 전주 대비 상승폭
    # bvsc_df['전주 대비 상승폭'] = bvsc_df['현재순위평균'] - bvsc_df['과거순위평균']
    # bvsc_df = bvsc_df[['현재순위평균', '곡', '가수', '전주 대비 상승폭', '사이트', '과거순위평균']]
    # top50_100_df = pd.concat([top50_100_df, bvsc_df])

    # 전주 대비 상승폭
    bvsc_df['전주 대비 상승폭'] = bvsc_df['전주순위평균'] - bvsc_df['이번주순위평균']
    bvsc_df = bvsc_df[['이번주순위평균', '곡', '가수', '전주 대비 상승폭', '사이트', '전주순위평균']].reset_index(drop=True)
    top50_100_df = pd.concat([top50_100_df, bvsc_df])

# Top50~100위 곡 중 이상치 곡만 추출
# save_folder2 = 'c:/data/Wantreez/Crawling/music/crawled_data/outlier_data/{new_start_date}_{new_end_date}'
outlier_file_name = f'{new_start_date}_{new_end_date}_total_outlier.xlsx'
outlier_path = os.path.join(save_folder2, outlier_file_name)
outlier_df = pd.read_excel(outlier_path)

top50_100_outlier_df = pd.DataFrame()
for i in range(outlier_df.shape[0]):
    title = outlier_df['곡'][i]
    artist = outlier_df['가수'][i]
    temp = top50_100_df[ (top50_100_df['곡'] == title) & (top50_100_df['가수'] == artist)].reset_index(drop=True)
    top50_100_outlier_df = pd.concat([top50_100_outlier_df, temp], ignore_index=True)

# 파일 저장
file_name3 = f'{new_start_date}_{new_end_date}_Top50_100_rank_change_df.xlsx'
save_top50_100_outlier_path = os.path.join(save_folder2, file_name3)
top50_100_outlier_df.to_excel(save_top50_100_outlier_path, index=False, encoding='utf-8')
print(f'{file_name3} 출력완료.')
# Out:
# 2022-05-16_2022-05-22_Top50_100_rank_change_df.xlsx 출력완료.

# %% [markdown]
# # 코드 마지막
