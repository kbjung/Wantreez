# %% [markdown]
# # 멜론 파일 확인

# %% [markdown]
# ## 라이브러리

# %%
import pandas as pd
import os

# %%
os.listdir()
# Out:
# ['day_genie.ipynb',
#  'live_flo.ipynb',
#  'live_genie.ipynb',
#  'live_melon.ipynb',
#  'live_soribada.ipynb',
#  'live_vibe.ipynb',
#  'melon_crawling_test.ipynb',
#  'melon_file_check.ipynb',
#  'month_genie.ipynb',
#  'month_melon.ipynb',
#  'README.md',
#  'test_graph_genie2022_1_3.ipynb',
#  'week_genie.ipynb',
#  'week_melon.ipynb']

# %%
os.chdir('../crawling_data/week_melon')

# %%
file_list = os.listdir()
type(file_list)
# Out:
# list

# %%
file_list
# Out:
# ['week_melon_20220103.xlsx',
#  'week_melon_20220110.xlsx',
#  'week_melon_20220117.xlsx',
#  'week_melon_20220124.xlsx',
#  'week_melon_20220131.xlsx',
#  'week_melon_20220207.xlsx',
#  'week_melon_20220214.xlsx',
#  'week_melon_20220221.xlsx',
#  'week_melon_20220228.xlsx',
#  'week_melon_20220307.xlsx',
#  'week_melon_20220314.xlsx',
#  'week_melon_20220321.xlsx',
#  'week_melon_20220328.xlsx']

# %% [markdown]
# ## week 파일 변환

# %%
for one in file_list:
    week = pd.read_excel(one)
    week['앨범'] = week['앨범'].str.strip()
    week.to_excel(one, index=False)

# %% [markdown]
# ## month check

# %%
os.chdir('../month_melon')

# %%
os.listdir()
# Out:
# ['month_melon_20220101.xlsx',
#  'month_melon_20220201.xlsx',
#  'month_melon_20220301.xlsx']

# %%
month01 = pd.read_excel('month_melon_20220101.xlsx')

# %%
month01.head(50)
# Out:
#             날짜  순위                                               곡  \
# 0   2022-01-01   1                                            취중고백
# 1   2022-01-01   2          회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)
# 2   2022-01-01   3                 Counting Stars (Feat. Beenzino)
# 3   2022-01-01   4                   리무진 (Feat. MINO) (Prod. GRAY)
# 4   2022-01-01   5                                          ELEVEN
# 5   2022-01-01   6                                             겨울잠
# 6   2022-01-01   7                                       사랑은 늘 도망가
# 7   2022-01-01   8                                Dreams Come True
# 8   2022-01-01   9                                눈이 오잖아(Feat.헤이즈)
# 9   2022-01-01  10  만남은 쉽고 이별은 어려워 (Feat. Leellamarz) (Prod. TOIL)
# 10  2022-01-01  11                                   다정히 내 이름을 부르면
# 11  2022-01-01  12                                 strawberry moon
# 12  2022-01-01  13                                             신호등
# ...

# %% [markdown]
# # 코드 마지막
