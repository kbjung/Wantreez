# %% [markdown]
# # Insta

# %% [markdown]
# ## 라이브러리

# %%
from selenium import webdriver
import chromedriver_autoinstaller as ca

# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
import os, time, random
from datetime import datetime
from numpy import nan

# %%
import getpass

# %% [markdown]
# ## 준비

# %% [markdown]
# ### 폴더 생성

# %%
# 현재 파일 위치 확인
code_path = os.getcwd().replace('\\', '/')
code_path
# Out:
# 'c:/data/Wantreez/Crawling/incheon'

# %%
# 폴더 생성
crawled_folder_path = code_path + '/crawled_data/insta/'
os.makedirs(crawled_folder_path, exist_ok=True)

# %% [markdown]
# ### 드라이버 확인 및 설치

# %%
# 크롬 드라이버 버전 확인
chrome_ver = ca.get_chrome_version().split('.')[0]
chrome_ver
# Out:
# '100'

# %%
# 크롬 드라이버 설치 확인 & 설치
try:
    driver = webdriver.Chrome(code_path + f'/{chrome_ver}/' + 'chromedriver.exe')
except:
    ca.install(True, code_path + f'/{chrome_ver}/')
    driver = webdriver.Chrome(code_path + f'/{chrome_ver}/' + 'chromedriver.exe')
# Out:
# C:\Users\kbjung\AppData\Local\Temp/ipykernel_22304/2196619946.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(code_path + f'/{chrome_ver}/' + 'chromedriver.exe')

# %% [markdown]
# ## 페이지 접속

# %%
# 페이지 접속
url = 'https://www.instagram.com/p/CaYtI8VLLeI/?utm_source=ig_web_copy_link'
driver.get(url)
driver.implicitly_wait(3)
driver.maximize_window()

# %%
# 댓글 더 보기 클릭
more_view_button = driver.find_element_by_xpath('//*[@id="react-root"]/section/main/div/div[1]/article/div/div[2]/div/div[2]/div[1]/ul/li/div/button/div')
more_view_button.click()
time.sleep( random.uniform(0.5, 1) )
# Out:
# C:\Users\kbjung\AppData\Local\Temp/ipykernel_22304/2388954869.py:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   more_view_button = driver.find_element_by_xpath('//*[@id="react-root"]/section/main/div/div[1]/article/div/div[2]/div/div[2]/div[1]/ul/li/div/button/div')

# %%
# 로그인
id_box = driver.find_element_by_xpath('//*[@id="loginForm"]/div[1]/div[1]/div/label/input')
pw_box = driver.find_element_by_xpath('//*[@id="loginForm"]/div[1]/div[2]/div/label/input')
login_button = driver.find_element_by_xpath('//*[@id="loginForm"]/div[1]/div[3]/button')

id = input('id를 입력하세요.')
pw = getpass.getpass('비밀번호를 입력하세요.')
# Out:
# C:\Users\kbjung\AppData\Local\Temp/ipykernel_22304/4138997505.py:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   id_box = driver.find_element_by_xpath('//*[@id="loginForm"]/div[1]/div[1]/div/label/input')
# C:\Users\kbjung\AppData\Local\Temp/ipykernel_22304/4138997505.py:3: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   pw_box = driver.find_element_by_xpath('//*[@id="loginForm"]/div[1]/div[2]/div/label/input')
# C:\Users\kbjung\AppData\Local\Temp/ipykernel_22304/4138997505.py:4: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   login_button = driver.find_element_by_xpath('//*[@id="loginForm"]/div[1]/div[3]/button')

# %%
id_box.send_keys(id)
time.sleep( random.uniform(0.5, 0.8))

pw_box.send_keys(pw)
time.sleep( random.uniform(0.5, 0.8))

login_button.click()
time.sleep( random.uniform(0.5, 0.8))

# %%
# 페이지 접속
url = 'https://www.instagram.com/p/CaYtI8VLLeI/?utm_source=ig_web_copy_link'
driver.get(url)
driver.implicitly_wait(3)
driver.maximize_window()

# %%
# 댓글 더 보기 클릭
count = 0
while True:
    try:
        more_view_button = driver.find_element_by_xpath('//*[@id="react-root"]/section/main/div/div[1]/article/div/div[2]/div/div[2]/div[1]/ul/li/div/button')
        more_view_button.click()
        time.sleep( random.uniform(0.5, 1) )
    except:
        break
    count += 1
print(f'더 보기 클릭 횟수 : {count}')
# Out:
# C:\Users\kbjung\AppData\Local\Temp/ipykernel_22304/6136485.py:5: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   more_view_button = driver.find_element_by_xpath('//*[@id="react-root"]/section/main/div/div[1]/article/div/div[2]/div/div[2]/div[1]/ul/li/div/button')
# 더 보기 클릭 횟수 : 25

# %% [markdown]
# ## 답글 보기 버튼 클릭

# %%
for i, one in enumerate(ul_soup):
    try:
        temp = one.find('li', '_61Di1').find('button', 'sqdOP yWX7d y3zKF')
        print(i)
    except:
        pass
# Out:
# 83
# 95
# 120
# 131
# 136
# 163

# %%
show_reply_buttons = driver.find_elements_by_css_selector('ul > li > div > button')
len(show_reply_buttons)
# Out:
# C:\Users\kbjung\AppData\Local\Temp/ipykernel_22304/1915660490.py:1: DeprecationWarning: find_elements_by_css_selector is deprecated. Please use find_elements(by=By.CSS_SELECTOR, value=css_selector) instead
#   show_reply_buttons = driver.find_elements_by_css_selector('ul > li > div > button')
# 6

# %%
for i in range(2):
    for one_show_reply_button in show_reply_buttons:
        if '보기' in one_show_reply_button.text:
            one_show_reply_button.click()
            time.sleep( random.uniform(0.5, 1) )
        elif '숨기기' in one_show_reply_button.text:
            pass

# %% [markdown]
# ## 수집

# %%
soup = bs(driver.page_source, 'lxml')
div_soup = soup.find_all('div', 'ZyFrc')[2:] # 첫번째 요소는 본문이라 제거
len(div_soup)
# Out:
# 505

# %% [markdown]
# ### id

# %%
div_soup[84].find('h3', '_6lAjh').find('a', 'sqdOP yWX7d _8A5w5 ZIAjV').text
# Out:
# 'minjija1367'

# %%
div_soup[85].find('h3', '_6lAjh').find('a', 'sqdOP yWX7d _8A5w5 ZIAjV').text
# Out:
# 'shin369999'

# %%
div_soup[86].find('h3', '_6lAjh').find('a', 'sqdOP yWX7d _8A5w5 ZIAjV').text
# Out:
# 'shin369999'

# %%
div_soup[82].find('a', 'sqdOP yWX7d _8A5w5 ZIAjV').text
# Out:
# 'yesman0024'

# %%
div_soup[82].find('span', '_7UhW9 xLCgt MMzan KV-D4 se6yk T0kll').text.replace('\xa0', '')
# Out:
# '😃@yiioi0 @lucky._.mi @jokyoungnam @sunghee8141@weonjaeweon473 @weonhyeongjun949 @gimjiseon617 ..함께해요'

# %%
div_soup[83].find('a', 'sqdOP yWX7d _8A5w5 ZIAjV').text
# Out:
# 'minjija1367'

# %%
div_soup[83].find('span', '_7UhW9 xLCgt MMzan KV-D4 se6yk T0kll').text.replace('\xa0', '')
# Out:
# '@icouncil103 #인천광역시의회 팔로우완료❇ 좋아요❤️ 참여완료❤️ 🙋\u200d♀️정답: 3번 ❤️ 300만  인천시민과 함께하는 #인천광역시의회 😎👍 겸손하게 소통하고 시민이 공감하는의회 #인천광역시의회 💙 많은분들의 관심과 사랑받으시고 애정듬뿍담아응원합니다🌷💐🌸🌻🌷💐🌸🌷💐🌻🌸 길어진 코로나로 지치고 힘들지만 조금만 더 힘내고 방역수칙 잘지켜 마스크벗고 웃을수있는 평온한일상이 오길 조금더 힘내보아요. 토닥토닥 위로받고싶은 요즘 따뜻한나눔 감사드려요ㆍ 😍😍 우리 조금만 더 힘내고 건강챙겨요^---^🍀 2022년 더욱더 반짝반짝 빛나는한해 되시길 바래요🌈🌈🌟🌟🌟🌟🌟'

# %%
div_soup[84].find('a', 'sqdOP yWX7d _8A5w5 ZIAjV').text
# Out:
# 'minjija1367'

# %%
div_soup[84].find('span', '_7UhW9 xLCgt MMzan KV-D4 se6yk T0kll').text.replace('\xa0', '')
# Out:
# '@minjija1367 함께해요🌼🌼 @shin369999 @hyonga123 @limja_1117 @eunhwaim26 @komram1004 @bagmigyeong9304 @herostop12 @hyejin9008 @gmlwjd8685'

# %%
div_soup[85].find('a', 'sqdOP yWX7d _8A5w5 ZIAjV').text
# Out:
# 'shin369999'

# %%
div_soup[85].find('span', '_7UhW9 xLCgt MMzan KV-D4 se6yk T0kll').text.replace('\xa0', '')
# Out:
# '함께해요🙌 @gjdlsdk @eunhwaim26 @limja_1117 @jaeeun3377 @gimjiseon617 @herostop12 @bagmigyeong9304 @ssm361 @kkinn_1013 @tlsalwk136'

# %%
div_soup[86].find('a', 'sqdOP yWX7d _8A5w5 ZIAjV').text
# Out:
# 'shin369999'

# %%
div_soup[86].find('span', '_7UhW9 xLCgt MMzan KV-D4 se6yk T0kll').text.replace('\xa0', '')
# Out:
# '함께해요🙌  @hyeran7512__ @tm_ty_th_mom@inseong_cjm @loveyou_is_0402 @mjh4357 @ddangkong154 @ioi3039 @minmoo42 @mi.yuui @woolovemom'

# %%
len(div_soup)
# Out:
# 505

# %%
# 작성자
id_list = []
for one in div_soup:
    temp = one.find('a', 'sqdOP yWX7d _8A5w5 ZIAjV').text
    id_list.append(temp)
len(id_list)
# Out:
# 505

# %%
# 내용
text_list = []
for one in div_soup:
    temp = one.find('span', '_7UhW9 xLCgt MMzan KV-D4 se6yk T0kll').text.replace('\xa0', '')
    text_list.append(temp)
len(text_list)
# Out:
# 505

# %% [markdown]
# ### 답글 구분

# %%
div_soup[83].parent['class']
# Out:
# ['Mr508']

# %%
div_soup[84].parent['class']
# Out:
# ['TCSYW']

# %%
div_soup[84].parent['class'][0] == 'TCSYW'
# Out:
# True

# %%
num = 83
if div_soup[num].parent['class'][0] == 'Mr508':
    is_reply = nan
elif div_soup[num].parent['class'][0] == 'TCSYW':
    is_reply = '답글'
is_reply
# Out:
# nan

# %%
num = 84
if div_soup[num].parent['class'][0] == 'Mr508':
    is_reply = nan
elif div_soup[num].parent['class'][0] == 'TCSYW':
    is_reply = '답글'
is_reply
# Out:
# '답글'

# %%
is_reply_list = []
for one in div_soup:
    if one.parent['class'][0] == 'Mr508':
        is_reply = nan
    elif one.parent['class'][0] == 'TCSYW':
        is_reply = '답글'
    is_reply_list.append(is_reply)
len(is_reply_list)
# Out:
# 505

# %%
is_reply_list[83:86]
# Out:
# [nan, '답글', nan]

# %% [markdown]
# ### 날짜

# %%
div_soup[83].find('time')['datetime']
# Out:
# '2022-02-25T17:31:11.000Z'

# %%
div_soup[83].find('time')['datetime'].split('.')[0].replace('T', ' ')
# Out:
# '2022-02-25 17:31:11'

# %%
div_soup[84].find('time')['datetime'].split('.')[0].replace('T', ' ')
# Out:
# '2022-02-25 17:31:26'

# %%
date_list = []
for one in div_soup:
    temp = one.find('time')['datetime'].split('.')[0].replace('T', ' ')
    date_list.append(temp)
len(date_list)
# Out:
# 505

# %% [markdown]
# ### 좋아요 수

# %%
div_soup[0].find('div', '_7UhW9 PIoXz MMzan _0PwGv uL8Hv').find_all('div', '_7UhW9 PIoXz qyrsm _0PwGv uL8Hv T0kll')[0].text
# Out:
# '좋아요 1개'

# %%
div_soup[0].find('div', '_7UhW9 PIoXz MMzan _0PwGv uL8Hv').find_all('div', '_7UhW9 PIoXz qyrsm _0PwGv uL8Hv T0kll')[1].text
# Out:
# '답글 달기'

# %%
len(div_soup[0].find('div', '_7UhW9 PIoXz MMzan _0PwGv uL8Hv').find_all('div', '_7UhW9 PIoXz qyrsm _0PwGv uL8Hv T0kll'))
# Out:
# 2

# %%
# 좋아요 없는 경우 태그가 업어짐.
# 조건을 걸어야 함.
div_soup[11].find('div', '_7UhW9 PIoXz MMzan _0PwGv uL8Hv').find_all('div', '_7UhW9 PIoXz qyrsm _0PwGv uL8Hv T0kll')[0].text
# Out:
# '답글 달기'

# %%
temp = div_soup[0].find('div', '_7UhW9 PIoXz MMzan _0PwGv uL8Hv').find_all('div', '_7UhW9 PIoXz qyrsm _0PwGv uL8Hv T0kll')
idx = 100
for i, one in enumerate(temp):
    if '좋아요' in one.text:
        print(temp[i].text)
    else:
        pass
if i == 100:
    print(0)
# Out:
# 좋아요 1개

# %%
temp = div_soup[11].find('div', '_7UhW9 PIoXz MMzan _0PwGv uL8Hv').find_all('div', '_7UhW9 PIoXz qyrsm _0PwGv uL8Hv T0kll')
idx = 100
for i, one in enumerate(temp):
    if '좋아요' in one.text:
        idx = i
    else:
        pass
if idx != 100:
    print(temp[idx].text)
else:
    print(nan)
# Out:
# nan

# %%
temp = div_soup[0].find('div', '_7UhW9 PIoXz MMzan _0PwGv uL8Hv').find_all('div', '_7UhW9 PIoXz qyrsm _0PwGv uL8Hv T0kll')
idx = 100
for i, one in enumerate(temp):
    if '좋아요' in one.text:
        idx = i
    else:
        pass
if idx != 100:
    print(temp[idx].text)
else:
    print(nan)
int(temp[idx].text.split(' ')[-1].replace('개', ''))
# Out:
# 좋아요 1개
# 1

# %%
num_like_list = []
for one in div_soup:
    try:
        fh_buttons = one.find('div', '_7UhW9 PIoXz MMzan _0PwGv uL8Hv').find_all('div', '_7UhW9 PIoXz qyrsm _0PwGv uL8Hv T0kll')
        idx = 100
        for i, one_fh_button in enumerate(fh_buttons):
            if '좋아요' in one_fh_button.text:
                idx = i
            else:
                pass
        if idx != 100:
            num_like = int(fh_buttons[idx].text.split(' ')[-1].replace('개', ''))
        else:
            num_like = nan
    except:
        num_like = nan
    num_like_list.append(num_like)
len(num_like_list)
# Out:
# 505

# %%
num_like_list[5:15]
# Out:
# [1, 1, 1, 1, 1, 2, nan, 1, 3, 1]

# %% [markdown]
# ### 친구소환수

# %%
len(div_soup[83].find_all('a', 'notranslate'))
# Out:
# 1

# %%
len(div_soup[84].find_all('a', 'notranslate'))
# Out:
# 10

# %%
len(div_soup[89].find_all('a', 'notranslate'))
# Out:
# 0

# %%
num_summon_friend_list = []
for one in div_soup:
    try:
        temp = one.find_all('a', 'notranslate')
        num_summon_friend = len(temp)
    except:
        num_summon_friend = 0
    num_summon_friend_list.append(num_summon_friend)
len(num_summon_friend_list)
# Out:
# 505

# %%
num_summon_friend_list[80:90]
# Out:
# [5, 4, 6, 1, 10, 10, 10, 2, 10, 0]

# %% [markdown]
# ### 답글수

# %%
div_soup[82].parent['class'][0]
# Out:
# 'Mr508'

# %%
num = 82
if div_soup[num].parent['class'][0] == 'Mr508':
    try:
        temp = len(div_soup[num].parent.find('ul', 'TCSYW').find_all('div', 'ZyFrc'))
        print(temp)
    except:
        print(0)
else:
    print(0)
# Out:
# 0

# %%
div_soup[83].parent['class'][0]
# Out:
# 'Mr508'

# %%
num = 83
if div_soup[num].parent['class'][0] == 'Mr508':
    try:
        temp = len(div_soup[num].parent.find('ul', 'TCSYW').find_all('div', 'ZyFrc'))
        print(temp)
    except:
        print(0)
else:
    print(0)
# Out:
# 1

# %%
div_soup[168].find('a', 'sqdOP yWX7d _8A5w5 ZIAjV').text
# Out:
# 'cocoraramom'

# %%
num = 168
if div_soup[num].parent['class'][0] == 'Mr508':
    try:
        temp = len(div_soup[num].parent.find('ul', 'TCSYW').find_all('div', 'ZyFrc'))
        print(temp)
    except:
        print(0)
else:
    print(0)
# Out:
# 2

# %%
div_soup[169].find('a', 'sqdOP yWX7d _8A5w5 ZIAjV').text
# Out:
# 'cocoraramom'

# %%
num = 169
if div_soup[num].parent['class'][0] == 'Mr508':
    try:
        temp = len(div_soup[num].parent.find('ul', 'TCSYW').find_all('div', 'ZyFrc'))
        print(temp)
    except:
        print(0)
else:
    print(0)
# Out:
# 0

# %%
num_like_list[168:171]
# Out:
# [2, 3, 1]

# %%
num_re_reply_list = []
for one in div_soup:
    if one.parent['class'][0] == 'Mr508':
        try:
            temp = len(one.parent.find('ul', 'TCSYW').find_all('div', 'ZyFrc'))
            num_re_reply = temp
        except:
            num_re_reply = 0
    else:
        num_re_reply = 0
    num_re_reply_list.append(num_re_reply)
len(num_re_reply_list)
# Out:
# 505

# %% [markdown]
# ### 고유번호

# %%
div_soup[168].find('a', 'gU-I7')['href']
# Out:
# '/p/CaYtI8VLLeI/c/17980877617471212/'

# %%
div_soup[168].find('a', 'gU-I7')['href'].split('/')
# Out:
# ['', 'p', 'CaYtI8VLLeI', 'c', '17980877617471212', '']

# %%
type(div_soup[168].find('a', 'gU-I7')['href'].split('/')[-2])
# Out:
# str

# %%
unique_num_list = []
for one in div_soup:
    temp = one.find('a', 'gU-I7')['href'].split('/')[-2]
    unique_num_list.append(temp)
len(unique_num_list)
# Out:
# 505

# %%
unique_num_list[1]
# Out:
# '17925948671142600'

# %% [markdown]
# ### 작성자URL

# %%
div_soup[168].find('a', 'sqdOP yWX7d _8A5w5 ZIAjV')['href']
# Out:
# '/cocoraramom/'

# %%
'https://www.instagram.com' + div_soup[168].find('a', 'sqdOP yWX7d _8A5w5 ZIAjV')['href']
# Out:
# 'https://www.instagram.com/cocoraramom/'

# %%
writer_url_list = []
for one in div_soup:
    temp = one.find('a', 'sqdOP yWX7d _8A5w5 ZIAjV')['href']
    writer_url = 'https://www.instagram.com' + temp
    writer_url_list.append(writer_url)
len(writer_url_list)
# Out:
# 505

# %% [markdown]
# ## 정리

# %%
id_list = []
text_list = []
is_reply_list = []
date_list = []
num_like_list = []
num_summon_friend_list = []
num_re_reply_list = []
unique_num_list = []
writer_url_list = []

for one in div_soup:
    # 작성자
    temp = one.find('a', 'sqdOP yWX7d _8A5w5 ZIAjV').text
    id_list.append(temp)

    # 내용
    temp = one.find('span', '_7UhW9 xLCgt MMzan KV-D4 se6yk T0kll').text.replace('\xa0', '')
    text_list.append(temp)

    # 답글 구분
    if one.parent['class'][0] == 'Mr508':
        is_reply = nan
    elif one.parent['class'][0] == 'TCSYW':
        is_reply = '답글'
    is_reply_list.append(is_reply)

    # 날짜
    temp = one.find('time')['datetime'].split('.')[0].replace('T', ' ')
    date_list.append(temp)

    # 좋아요 수
    try:
        fh_buttons = one.find('div', '_7UhW9 PIoXz MMzan _0PwGv uL8Hv').find_all('div', '_7UhW9 PIoXz qyrsm _0PwGv uL8Hv T0kll')
        idx = 100
        for i, one_fh_button in enumerate(fh_buttons):
            if '좋아요' in one_fh_button.text:
                idx = i
            else:
                pass
        if idx != 100:
            num_like = int(fh_buttons[idx].text.split(' ')[-1].replace('개', ''))
        else:
            num_like = nan
    except:
        num_like = nan
    num_like_list.append(num_like)

    # 친구소환수
    try:
        temp = one.find_all('a', 'notranslate')
        num_summon_friend = len(temp)
    except:
        num_summon_friend = 0
    num_summon_friend_list.append(num_summon_friend)

    # 답글수
    if one.parent['class'][0] == 'Mr508':
        try:
            temp = len(one.parent.find('ul', 'TCSYW').find_all('div', 'ZyFrc'))
            num_re_reply = temp
        except:
            num_re_reply = 0
    else:
        num_re_reply = 0
    num_re_reply_list.append(num_re_reply)

    # 고유번호
    temp = one.find('a', 'gU-I7')['href'].split('/')[-2]
    unique_num_list.append(temp)

    # 작성자URL
    temp = one.find('a', 'sqdOP yWX7d _8A5w5 ZIAjV')['href']
    writer_url = 'https://www.instagram.com' + temp
    writer_url_list.append(writer_url)

# %% [markdown]
# ## 결과 확인

# %%
print(len(id_list))
print(len(text_list))
print(len(is_reply_list))
print(len(date_list))
print(len(num_like_list))
print(len(num_summon_friend_list))
print(len(num_re_reply_list))
print(len(unique_num_list))
print(len(writer_url_list))
# Out:
# 505
# 505
# 505
# 505
# 505
# 505
# 505
# 505
# 505

# %% [markdown]
# ## df

# %%
dict = {'작성일':date_list, '고유번호':unique_num_list, '답글구분':is_reply_list,
        '작성자':id_list, '작성자URL':writer_url_list, '내용':text_list,
        '답글수':num_re_reply_list, '친구소환수':num_summon_friend_list}
df = pd.DataFrame(dict)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   작성일     505 non-null    object
#  1   고유번호    505 non-null    int64
#  2   답글구분    7 non-null      object
#  3   작성자     505 non-null    object
#  4   작성자URL  505 non-null    object
#  5   내용      505 non-null    object
#  6   답글수     505 non-null    int64
#  7   친구소환수   505 non-null    int64
# dtypes: int64(3), object(5)
# memory usage: 31.7+ KB

# %%
df.head()
# Out:
#                    작성일               고유번호 답글구분           작성자  \
# 0  2022-02-25 05:00:25  17939717656795384  NaN       ujiho83
# 1  2022-02-26 14:37:47  17925948671142600  NaN  imjihyeon335
# 2  2022-02-25 21:11:25  17934777361996268  NaN      red79_79
# 3  2022-02-25 06:41:11  18197207746144070  NaN      seonmogo
# 4  2022-02-26 13:22:12  17920478654198723  NaN    iso_810811
#
#                                     작성자URL  \
# 0       https://www.instagram.com/ujiho83/
# 1  https://www.instagram.com/imjihyeon335/
# 2      https://www.instagram.com/red79_79/
# 3      https://www.instagram.com/seonmogo/
# 4    https://www.instagram.com/iso_810811/
#
#                                                   내용  답글수  친구소환수
# 0                         정답:3번 @gwagjiyu7 @sysy1956    0      2
# 1  🌈 정답 3번 🌈 #인천광역시의회 #인천시의회 언제나 응원합니다 인님들 모두모두 함...    0      8
# 2  정답 » 3번❤️ 언제나 함께 공감 할 수 있는 이야기🍀다양한 콘텐츠로 꿀 정보 부...    0     10
# 3  정답 : 3번❤️❤️ @joy486486 @jo_ys1779 @kang4524452...    0      4
# ...

# %%
# 최종 df
final_df = df.copy()

# %% [markdown]
# ## 파일로 출력

# %%
today_date = datetime.today().strftime('%Y%m%d_%H%M%S')
today_date
# Out:
# '20220420_164536'

# %%
today_date = datetime.today().strftime('%Y%m%d_%H%M%S')
file_name = f'insta_{today_date}.xlsx'
final_df.to_excel(crawled_folder_path + '/' + file_name, index=False, encoding='utf-8')
print(f'{file_name} 출력완료')
# Out:
# insta_20220420_164658.xlsx 출력완료

# %% [markdown]
# # 코드 마지막
